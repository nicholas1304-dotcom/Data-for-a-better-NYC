# %%
import pandas as pd
df = pd.read_csv('export.csv')

# %%
df
# Out:
#       Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0         18220152                       808768                        3
# 1         18220153                       808768                        3
# 2         18220154                       808768                        3
# 3         18223815                       286990                        3
# 4         18223816                       286990                        3
# ...            ...                          ...                      ...
# 4292      18941379                       230486                        3
# 4293      18941380                       230486                        3
# 4294      18941381                       230486                        3
# 4295      18941382                       230486                        3
# 4296      18957183                       804780                        1
#
#      Primary Borough Name Primary House Number Primary Low House Number  \
# ...

# %%
df.isna().sum()
# Out:
# Violation ID                                  0
# Primary Building Identifier                   0
# Primary Boro Identifier                       0
# Primary Borough Name                          0
# Primary House Number                          0
# Primary Low House Number                      0
# Primary High House Number                     0
# Primary Street Name                           0
# Primary Postcode                              0
# Development Name                              0
# TDS Number                                    0
# Stairhall Number                              0
# NYCHA Address Section BoroID                  0
# NYCHA Address Section Borough                 0
# NYCHA Address Section House Number            0
# NYCHA Address Section Street Name             0
# NYCHA Address Section PostCode                0
# Apartment                                    63
# Story                                         0
# Block                                         0
# ...

# %%
df.isna().any(axis=1).sum()
# Out:
# np.int64(94)

# %%
#show empty apartment row 
df[df['Apartment'].isna()]
# Out:
#       Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 8         18223820                       286990                        3
# 9         18223821                       286990                        3
# 19        18217480                       809272                        3
# 21        18220067                       217152                        3
# 22        18220068                       217152                        3
# ...            ...                          ...                      ...
# 4113      19013349                       809589                        3
# 4123      19013350                       809589                        3
# 4134      19043044                       820574                        1
# 4244      18937638                       804794                        1
# 4295      18941382                       230486                        3
#
#      Primary Borough Name Primary House Number Primary Low House Number  \
# ...

# %%
df.isna().sum()
# Out:
# Violation ID                                  0
# Primary Building Identifier                   0
# Primary Boro Identifier                       0
# Primary Borough Name                          0
# Primary House Number                          0
# Primary Low House Number                      0
# Primary High House Number                     0
# Primary Street Name                           0
# Primary Postcode                              0
# Development Name                              0
# TDS Number                                    0
# Stairhall Number                              0
# NYCHA Address Section BoroID                  0
# NYCHA Address Section Borough                 0
# NYCHA Address Section House Number            0
# NYCHA Address Section Street Name             0
# NYCHA Address Section PostCode                0
# Apartment                                    63
# Story                                         0
# Block                                         0
# ...

# %%
df[df[['Primary Building Identifier', 'Class', 'Violation Description']].isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Violation ID, Primary Building Identifier, Primary Boro Identifier, Primary Borough Name, Primary House Number, Primary Low House Number, Primary High House Number, Primary Street Name, Primary Postcode, Development Name, TDS Number, Stairhall Number, NYCHA Address Section BoroID, NYCHA Address Section Borough, NYCHA Address Section House Number, NYCHA Address Section Street Name, NYCHA Address Section PostCode, Apartment, Story, Block, Lot, Violation Description, Class, Inspection Date, Approved Date, Order Number, Issued in Error, Latitude, Longitude, Community Board, Council District, BIN, BBL, Census Tract (2020), Neighborhood Tabulation Area (NTA) (2020)]
# Index: []
#
# [0 rows x 35 columns]

# %%
df['Violation Description'].head()
# Out:
# 0    § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 1    § 27-2026, 2027 HMC: PROPERLY REPAIR THE SOURC...
# 2    § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 3    § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 4    § 27-2017.3 HMC: TRACE AND REPAIR THE SOURCE A...
# Name: Violation Description, dtype: str

# %%
df[['Primary Building Identifier', 'Class', 'Violation Description']].head()
# Out:
#    Primary Building Identifier Class  \
# 0                       808768     B
# 1                       808768     B
# 2                       808768     B
# 3                       286990     B
# 4                       286990     B
#
#                                Violation Description
# 0  § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 1  § 27-2026, 2027 HMC: PROPERLY REPAIR THE SOURC...
# 2  § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 3  § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 4  § 27-2017.3 HMC: TRACE AND REPAIR THE SOURCE A...

# %%
# Top 10 building violations 
plt.figure(figsize=(10,6))
df['Violation Description'].value_counts().head(10).plot(kind='barh')
plt.xlabel('Count')
plt.title('Top 10 Violation Descriptions')
plt.gca().invert_yaxis()
plt.show()

# %%
#Broughs top building complaints


import seaborn as sns

top_violations = df['Violation Description'].value_counts().head(10).index
df_top = df[df['Violation Description'].isin(top_violations)]

plt.figure(figsize=(14,8))
sns.countplot(data=df_top, y='Violation Description', hue='Primary Borough Name', order=top_violations)
plt.xlabel('Count')
plt.title('Top 10 Violation Descriptions by Borough')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1690/1002852095.py:12: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
df[['Primary Borough Name','Primary Building Identifier', 'Class', 'Violation Description']].head()
# Out:
#   Primary Borough Name  Primary Building Identifier Class  \
# 0             BROOKLYN                       808768     B
# 1             BROOKLYN                       808768     B
# 2             BROOKLYN                       808768     B
# 3             BROOKLYN                       286990     B
# 4             BROOKLYN                       286990     B
#
#                                Violation Description
# 0  § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 1  § 27-2026, 2027 HMC: PROPERLY REPAIR THE SOURC...
# 2  § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 3  § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 4  § 27-2017.3 HMC: TRACE AND REPAIR THE SOURCE A...

# %%
df[['Primary Borough Name','Primary Building Identifier', 'Class', 'Violation Description',]].head()
# Out:
#   Primary Borough Name  Primary Building Identifier Class  \
# 0             BROOKLYN                       808768     B
# 1             BROOKLYN                       808768     B
# 2             BROOKLYN                       808768     B
# 3             BROOKLYN                       286990     B
# 4             BROOKLYN                       286990     B
#
#                                Violation Description
# 0  § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 1  § 27-2026, 2027 HMC: PROPERLY REPAIR THE SOURC...
# 2  § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 3  § 27-2005 ADM CODE  REPAIR THE BROKEN OR DEFEC...
# 4  § 27-2017.3 HMC: TRACE AND REPAIR THE SOURCE A...

# %%
df
# Out:
#       Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0         18220152                       808768                        3
# 1         18220153                       808768                        3
# 2         18220154                       808768                        3
# 3         18223815                       286990                        3
# 4         18223816                       286990                        3
# ...            ...                          ...                      ...
# 4292      18941379                       230486                        3
# 4293      18941380                       230486                        3
# 4294      18941381                       230486                        3
# 4295      18941382                       230486                        3
# 4296      18957183                       804780                        1
#
#      Primary Borough Name Primary House Number Primary Low House Number  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns=['Primary House Number', 'Primary Low House Number', 'Primary High House Number'])

# %%
df.columns.tolist()
# Out:
# ['Violation ID',
#  'Primary Building Identifier',
#  'Primary Boro Identifier',
#  'Primary Borough Name',
#  'Primary Street Name',
#  'Primary Postcode',
#  'Development Name',
#  'TDS Number',
#  'Stairhall Number',
#  'NYCHA Address Section BoroID',
#  'NYCHA Address Section Borough',
#  'NYCHA Address Section House Number',
#  'NYCHA Address Section Street Name',
#  'NYCHA Address Section PostCode',
#  'Apartment',
#  'Story',
#  'Block',
#  'Lot',
#  'Violation Description',
#  'Class',
#  'Inspection Date',
#  'Approved Date',
#  'Order Number',
#  'Issued in Error',
#  'Latitude',
#  'Longitude',
#  'Community Board',
#  'Council District',
#  'BIN',
#  'BBL',
#  'Census Tract (2020)',
#  'Neighborhood Tabulation Area (NTA) (2020)']

# %%
df
# Out:
#       Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0         18220152                       808768                        3
# 1         18220153                       808768                        3
# 2         18220154                       808768                        3
# 3         18223815                       286990                        3
# 4         18223816                       286990                        3
# ...            ...                          ...                      ...
# 4292      18941379                       230486                        3
# 4293      18941380                       230486                        3
# 4294      18941381                       230486                        3
# 4295      18941382                       230486                        3
# 4296      18957183                       804780                        1
#
#      Primary Borough Name         Primary Street Name  Primary Postcode  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#       Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0         18220152                       808768                        3
# 1         18220153                       808768                        3
# 2         18220154                       808768                        3
# 3         18223815                       286990                        3
# 4         18223816                       286990                        3
# ...            ...                          ...                      ...
# 4283      18937783                       809336                        3
# 4284      18937784                       809336                        3
# 4285      18937785                       809336                        3
# 4286      18937786                       809336                        3
# 4296      18957183                       804780                        1
#
#      Primary Borough Name         Primary Street Name  Primary Postcode  \
# ...

# %%
df = df.drop(columns=['Primary Boro Identifier'])

# %%
df
# Out:
#       Violation ID  Primary Building Identifier Primary Borough Name  \
# 0         18220152                       808768             BROOKLYN
# 1         18220153                       808768             BROOKLYN
# 2         18220154                       808768             BROOKLYN
# 3         18223815                       286990             BROOKLYN
# 4         18223816                       286990             BROOKLYN
# ...            ...                          ...                  ...
# 4283      18937783                       809336             BROOKLYN
# 4284      18937784                       809336             BROOKLYN
# 4285      18937785                       809336             BROOKLYN
# 4286      18937786                       809336             BROOKLYN
# 4296      18957183                       804780            MANHATTAN
#
#              Primary Street Name  Primary Postcode Development Name  \
# 0                LORRAINE STREET             11231    RED HOOK WEST
# ...

# %%
df =df.drop(columns=['NYCHA Address Section BoroID'])

# %%
df
# Out:
#       Violation ID  Primary Building Identifier Primary Borough Name  \
# 0         18220152                       808768             BROOKLYN
# 1         18220153                       808768             BROOKLYN
# 2         18220154                       808768             BROOKLYN
# 3         18223815                       286990             BROOKLYN
# 4         18223816                       286990             BROOKLYN
# ...            ...                          ...                  ...
# 4283      18937783                       809336             BROOKLYN
# 4284      18937784                       809336             BROOKLYN
# 4285      18937785                       809336             BROOKLYN
# 4286      18937786                       809336             BROOKLYN
# 4296      18957183                       804780            MANHATTAN
#
#              Primary Street Name  Primary Postcode Development Name  \
# 0                LORRAINE STREET             11231    RED HOOK WEST
# ...

# %%
f = df.drop(columns=['Community Board','Council District'])

# %%
df
# Out:
#       Violation ID  Primary Building Identifier Primary Borough Name  \
# 0         18220152                       808768             BROOKLYN
# 1         18220153                       808768             BROOKLYN
# 2         18220154                       808768             BROOKLYN
# 3         18223815                       286990             BROOKLYN
# 4         18223816                       286990             BROOKLYN
# ...            ...                          ...                  ...
# 4283      18937783                       809336             BROOKLYN
# 4284      18937784                       809336             BROOKLYN
# 4285      18937785                       809336             BROOKLYN
# 4286      18937786                       809336             BROOKLYN
# 4296      18957183                       804780            MANHATTAN
#
#              Primary Street Name  Primary Postcode Development Name  \
# 0                LORRAINE STREET             11231    RED HOOK WEST
# ...

# %%
all_boroughs = df['Primary Borough Name'].unique()

plt.figure(figsize=(14,8))
sns.countplot(data=df_top, y='Violation Description', hue='Primary Borough Name', 
              order=top_violations, hue_order=all_boroughs)
plt.xlabel('Count')
plt.title('Top 10 Violation Descriptions by Borough')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1690/494945222.py:9: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
for borough in ['STATEN ISLAND', 'QUEENS']:
    print(f"\n--- {borough} ---")
    print(df[df['Primary Borough Name'] == borough]['Violation Description'].value_counts().head(10))
# Out:
# --- STATEN ISLAND ---
# Violation Description
# HMC ADM CODE: § 27-2017.4 ABATE THE INFESTATION CONSISTING OF MICE IN THE  ENTIRE APARTMENT  LOCATED AT APT 8E, 8th STORY, 1st APARTMENT FROM NORTH AT EAST , SECTION "e-h"                                                                                                                                                      1
# 566 (B) 27-2021.4 HMC: ABATE THE NUISANCE CONSISTING OF PESTS. EVIDENCE OF  FLIES   IN THE  ENTIRE APARTMENT  LOCATED AT APT 8E, 8th STORY, 1st APARTMENT FROM NORTH AT EAST , SECTION "e-h"                                                                                                                                     1
# ...

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Primary Borough Name', order=df['Primary Borough Name'].value_counts().index)
plt.xlabel('Borough')
plt.ylabel('Number of Violations')
plt.title('Total Violations by Borough')
plt.xticks(rotation=45)
plt.show()

# %%
df
# Out:
#       Violation ID  Primary Building Identifier Primary Borough Name  \
# 0         18220152                       808768             BROOKLYN
# 1         18220153                       808768             BROOKLYN
# 2         18220154                       808768             BROOKLYN
# 3         18223815                       286990             BROOKLYN
# 4         18223816                       286990             BROOKLYN
# ...            ...                          ...                  ...
# 4283      18937783                       809336             BROOKLYN
# 4284      18937784                       809336             BROOKLYN
# 4285      18937785                       809336             BROOKLYN
# 4286      18937786                       809336             BROOKLYN
# 4296      18957183                       804780            MANHATTAN
#
#              Primary Street Name  Primary Postcode Development Name  \
# 0                LORRAINE STREET             11231    RED HOOK WEST
# ...

# %%
all_boroughs = df['Primary Borough Name'].unique()

plt.figure(figsize=(14,8))
sns.countplot(data=df_top, y='Violation Description', hue='Primary Borough Name', 
              order=top_violations, hue_order=all_boroughs)
plt.xlabel('Count')
plt.title('Top 10 Violation Descriptions by Borough')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#       Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0         18220152                       808768                        3
# 1         18220153                       808768                        3
# 2         18220154                       808768                        3
# 3         18223815                       286990                        3
# 4         18223816                       286990                        3
# ...            ...                          ...                      ...
# 4292      18941379                       230486                        3
# 4293      18941380                       230486                        3
# 4294      18941381                       230486                        3
# 4295      18941382                       230486                        3
# 4296      18957183                       804780                        1
#
#      Primary Borough Name Primary House Number Primary Low House Number  \
# ...

# %%
df = df.drop(columns=['Community Board','Council District'])

# %%
df = df.drop(columns=['Primary House Number', 'Primary Low House Number', 'Primary High House Number'])

# %%
df
# Out:
#       Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0         18220152                       808768                        3
# 1         18220153                       808768                        3
# 2         18220154                       808768                        3
# 3         18223815                       286990                        3
# 4         18223816                       286990                        3
# ...            ...                          ...                      ...
# 4292      18941379                       230486                        3
# 4293      18941380                       230486                        3
# 4294      18941381                       230486                        3
# 4295      18941382                       230486                        3
# 4296      18957183                       804780                        1
#
#      Primary Borough Name         Primary Street Name  Primary Postcode  \
# ...

# %%
df =df.drop(columns=['NYCHA Address Section BoroID'])

# %%
df =df.drop(columns=['Primary Boro Identifier'])

# %%
df
# Out:
#       Violation ID  Primary Building Identifier Primary Borough Name  \
# 0         18220152                       808768             BROOKLYN
# 1         18220153                       808768             BROOKLYN
# 2         18220154                       808768             BROOKLYN
# 3         18223815                       286990             BROOKLYN
# 4         18223816                       286990             BROOKLYN
# ...            ...                          ...                  ...
# 4292      18941379                       230486             BROOKLYN
# 4293      18941380                       230486             BROOKLYN
# 4294      18941381                       230486             BROOKLYN
# 4295      18941382                       230486             BROOKLYN
# 4296      18957183                       804780            MANHATTAN
#
#              Primary Street Name  Primary Postcode Development Name  \
# 0                LORRAINE STREET             11231    RED HOOK WEST
# ...

# %%
df = df.drop(columns=['Neighborhood Tabulation Area (NTA) (2020)'])

# %%
df
# Out:
#       Violation ID  Primary Building Identifier Primary Borough Name  \
# 0         18220152                       808768             BROOKLYN
# 1         18220153                       808768             BROOKLYN
# 2         18220154                       808768             BROOKLYN
# 3         18223815                       286990             BROOKLYN
# 4         18223816                       286990             BROOKLYN
# ...            ...                          ...                  ...
# 4292      18941379                       230486             BROOKLYN
# 4293      18941380                       230486             BROOKLYN
# 4294      18941381                       230486             BROOKLYN
# 4295      18941382                       230486             BROOKLYN
# 4296      18957183                       804780            MANHATTAN
#
#              Primary Street Name  Primary Postcode Development Name  \
# 0                LORRAINE STREET             11231    RED HOOK WEST
# ...

# %%
top_violations = df['Violation Description'].value_counts().head(10).index
df_top = df[df['Violation Description'].isin(top_violations)]

all_boroughs = df['Primary Borough Name'].unique()

plt.figure(figsize=(14,8))
sns.countplot(data=df_top, y='Violation Description', hue='Primary Borough Name', 
              order=top_violations, hue_order=all_boroughs)
plt.xlabel('Count')
plt.title('Top 10 Violation Descriptions by Borough')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1714/905461018.py:12: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
df['Inspection Date'] = pd.to_datetime(df['Inspection Date'], errors='coerce')
df['Approved Date'] = pd.to_datetime(df['Approved Date'], errors='coerce')

df['DaysToFix'] = (df['Approved Date'] - df['Inspection Date']).dt.days

print(df['DaysToFix'].describe())
# Out:
# count    4297.000000
# mean        1.575518
# std         6.662063
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max       183.000000
# Name: DaysToFix, dtype: float64

# %%
# Average Time To Fix Violation 

plt.figure(figsize=(8,5))
sns.barplot(data=df, x='Class', y='DaysToFix', estimator='mean')
plt.xlabel('Violation Class')
plt.ylabel('Average Days to Fix')
plt.title('Average Time to Fix by Violation Class')
plt.show()

# %%
# Total Violations By Borough
borough_pct = df['Primary Borough Name'].value_counts(normalize=True) * 100

plt.figure(figsize=(10,6))
borough_pct.plot(kind='bar')
plt.xlabel('Borough')
plt.ylabel('Percentage of Violations (%)')
plt.title('Violations by Borough (%)')
plt.xticks(rotation=45)
plt.show()

# %%
import plotly.express as px

fig = px.scatter_map(
    df_map,
    lat="Latitude",
    lon="Longitude",
    color="Primary Borough Name",
    zoom=9,
    height=600,
    map_style="open-street-map"
)
fig.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='Primary Borough Name', hue='Class', multiple='stack',
             shrink=0.8)
plt.xlabel('Borough')
plt.ylabel('Number of Violations')
plt.title('Total Violations by Borough (Stacked by Class)')
plt.xticks(rotation=45)
plt.legend(title='Class A,B,C')
plt.show()
# Out:
# /tmp/ipykernel_1714/3820940098.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Class A,B,C')

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Primary Borough Name', hue='Class', 
              order=df['Primary Borough Name'].value_counts().index)
plt.xlabel('Borough')
plt.ylabel('Number of Violations')
plt.title('Violations by Borough and Class')
plt.xticks(rotation=45)
plt.legend(title='Class')
plt.show()

# %%
df[df['Primary Borough Name'] == 'BRONX']['Primary Street Name']
# Out:
# 10      EAST 174 STREET
# 11      EAST 174 STREET
# 14      EAST 174 STREET
# 15      EAST 174 STREET
# 16      EAST 174 STREET
#              ...
# 4275    EAST 143 STREET
# 4276    EAST 143 STREET
# 4277    EAST 143 STREET
# 4278    EAST 143 STREET
# 4279    EAST 143 STREET
# Name: Primary Street Name, Length: 388, dtype: str

# %%
df_bronx = df[df['Primary Borough Name'] == 'BRONX']

pct_data = df_bronx['Class'].value_counts(normalize=True).mul(100).rename('Percentage').reset_index()

plt.figure(figsize=(8,5))
sns.barplot(data=pct_data, x='Class', y='Percentage')
plt.xlabel('Class')
plt.ylabel('Percentage of Violations (%)')
plt.title('Violation Class Breakdown — Bronx')
plt.show()

# %%
# Average Time To Fix Violation 

plt.figure(figsize=(8,5))
sns.barplot(data=df, x='Class', y='DaysToFix', estimator='mean')
plt.xlabel('Violation Class')
plt.ylabel('Average Days to Fix')
plt.title('Average Time to Fix by Violation Class')
plt.show()

# %%
# Total Violations By BRONX
import seaborn as sns

df_bronx = df[df['Primary Borough Name'] == 'BRONX']
pct_data = df_bronx['Class'].value_counts(normalize=True).mul(100).rename('Percentage').reset_index()

plt.figure(figsize=(8,5))
sns.barplot(data=pct_data, x='Class', y='Percentage')
plt.xlabel('Class')
plt.ylabel('Percentage of Violations (%)')
plt.title('Violation Class Breakdown — Bronx')
plt.show()

# %%
df_bronx = df[df['Primary Borough Name'] == 'BRONX']

plt.figure(figsize=(8,5))
sns.countplot(data=df_bronx, x='Class', order=df_bronx['Class'].value_counts().index)
plt.xlabel('Class')
plt.ylabel('Number of Violations')
plt.title('Violation Class Breakdown — Bronx')
plt.show()

# %%
Class A Violations (Non-Hazardous)
Conditions that are not immediately hazardous but violate the Housing Maintenance Code:

Peeling paint (non-lead areas)
Minor water leaks
Cracked plaster or walls
Loose floor tiles
Defective outlets or switches (non-hazardous)
Missing window screens
Minor vermin conditions
Damaged window sills
# Out:
#   Cell In[13], line 1
#     Class A Violations (Non-Hazardous)
#           ^
# SyntaxError: invalid syntax
