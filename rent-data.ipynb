# %%
import pandas as pd 
import seaborn as sns 
import plotly.express as px

df = pd.read_csv("Local_Law_44_-_Unit_Income_Rent_20260715.csv")
df
# Out:
#        ProjectID  BuildingID BedroomSize MaxAllowableIncome  TotalUnits  \
# 0          50206    287193.0        2-BR             0%-30%           1
# 1          50206    383480.0      STUDIO             0%-30%           1
# 2          50206    383478.0        2-BR             0%-30%           1
# 3          52674      4060.0        2-BR             0%-30%           1
# 4          52674     41105.0        2-BR             0%-30%           1
# ...          ...         ...         ...                ...         ...
# 20028      74117    811254.0     Unknown              Other           8
# 20029      74117    811257.0        3-BR              Other          32
# 20030      75555    127004.0        1-BR              Other          74
# 20031      75555    127004.0      Studio              Other          12
# 20032      75650    938231.0        1-BR              Other          80
#
#       MedianInitialLegalRent HighInitialLegalRent LowInitialLegalRent  \
# ...

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable
